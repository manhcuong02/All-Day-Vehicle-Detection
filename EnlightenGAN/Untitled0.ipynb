# %% [markdown]
# # Enlighten

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/EnLightenGAN
# !pip install -r requirement.txt

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/EnLightenGAN
# !python scripts/script.py --predict_video
# Out:
# /content/drive/MyDrive/ColabNotebooks/EnLightenGAN
# ------------ Options -------------
# D_P_times2: False
# IN_vgg: False
# aspect_ratio: 1.0
# batchSize: 1
# checkpoints_dir: ./checkpoints
# dataroot: ../test_dataset
# dataset_mode: unaligned
# display_id: 1
# display_port: 8097
# display_single_pane_ncols: 0
# display_winsize: 256
# fcn: 0
# fineSize: 256
# gpu_ids: [0]
# high_times: 400
# how_many: 50
# hybrid_loss: False
# identity: 0.0
# input_linear: False
# input_nc: 3
# instance_norm: 0.0
# isTrain: False
# l1: 10.0
# lambda_A: 10.0
# lambda_B: 10.0
# latent_norm: False
# latent_threshold: False
# lighten: False
# linear: False
# linear_add: False
# loadSize: 286
# low_times: 200
# max_dataset_size: inf
# model: single
# multiply: False
# nThreads: 4
# n_layers_D: 3
# n_layers_patchD: 3
# name: enlightening
# ndf: 64
# new_lr: False
# ngf: 64
# no_dropout: True
# no_flip: False
# no_vgg_instance: False
# noise: 0
# norm: instance
# norm_attention: False
# ntest: inf
# ...

# %%
import PIL.Image as Image

Image.open("save.jpg")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # TPH-YOLOV5

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/tph-yolov5
# !pip install -r requirements.txt

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/tph-yolov5
# !python detect.py --source /content/drive/MyDrive/ColabNotebooks/TRAFFIC_SURVEILANCE/data/videos/Xuanthuy.MOV --weights weights/yolov5l-xs-2.pt --img 1280

# %% [markdown]
# # YOLOv5

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/yolov5
# !pip install -r requirements.txt

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/yolov5
# !python detect_yolov5.py --weights weights/yolov5l6.pt --source /content/drive/MyDrive/ColabNotebooks/TRAFFIC_SURVEILANCE/data/videos/Xuanthuy.MOV --img 1280 --data data/coco.yaml --classes 0 1 2 3 5 7 --save-txt --device 0 --line-thickness 3
